# %%
# from google.colab import drive
# drive.mount('/content/drive')
# file_path = "drive/MyDrive/ECGR 4106/HW_3/"

# %% [markdown]
# Problem 1

# %%
import torch
import numpy as np 
import pandas as pd 
import torch.optim as optim
import torch.nn as nn
import collections
import torch.nn.functional as F


class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

from torchvision import datasets, transforms
data_path = '/data/'
cifar10 = datasets.CIFAR10(
    data_path, train=True, download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

cifar10_val = datasets.CIFAR10(
    data_path, train=False, download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /data/cifar-10-python.tar.gz to /data/
# Files already downloaded and verified

# %%
cifar10_train = [(img, label) for img, label in cifar10]
cifar10_test = [(img, label) for img, label in cifar10_val]

# %%
device = torch.device(
    "cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# cuda

# %%
class NetWidth(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 16, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16 * 32 * 32, 32)
        self.fc2 = nn.Linear(32, 10)
        
    def forward(self, x):
        out = torch.tanh(self.conv1(x))
        out = torch.tanh(self.conv2(out))
        out = out.view(-1, 16 * 32 * 32)
        out = torch.tanh(self.fc1(out))
        out = self.fc2(out)
        return out
        
class NetWidth2(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16 * 4 * 4, 32)
        self.fc2 = nn.Linear(32, 10)
        
    def forward(self, x):
        out = F.max_pool2d(torch.tanh(self.conv1(x)), 2)
        out = F.max_pool2d(torch.tanh(self.conv2(out)), 2)
        out = F.max_pool2d(torch.tanh(self.conv2(out)), 2)
        out = out.view(-1, 16 * 4 * 4)
        out = torch.tanh(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
train_loader = torch.utils.data.DataLoader(cifar10_train, batch_size=64,
                                           shuffle=False)
val_loader = torch.utils.data.DataLoader(cifar10_test, batch_size=64,
                                         shuffle=False)
all_acc_dict = collections.OrderedDict()

def validate(model, train_loader, val_loader):
    accdict = {}
    for name, loader in [("train", train_loader), ("val", val_loader)]:
        correct = 0
        total = 0

        with torch.no_grad():
            for imgs, labels in loader:
                imgs = imgs.to(device=device)
                labels = labels.to(device=device)
                outputs = model(imgs)
                _, predicted = torch.max(outputs, dim=1) # <1>
                total += labels.shape[0]
                correct += int((predicted == labels).sum())

        print("Accuracy {}: {:.2f}".format(name , correct / total))
        accdict[name] = correct / total
    return accdict

# %%
import datetime

def training_loop(n_epochs, optimizer, model, loss_fn, train_loader):
    for epoch in range(1, n_epochs + 1):
        loss_train = 0.0
        for imgs, labels in train_loader:
            imgs = imgs.to(device=device)  # <1>
            labels = labels.to(device=device)
            outputs = model(imgs)
            loss = loss_fn(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_train += loss.item()

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Training loss {}'.format(
                datetime.datetime.now(), epoch,
                loss_train / len(train_loader)))
            validate(model, train_loader, val_loader)

# %%
model = NetWidth().to(device=device)
optimizer = optim.SGD(model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 100,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)

validate(model, train_loader, val_loader)
# Out:
# 2022-03-20 00:08:48.179095 Epoch 1, Training loss 1.823598206805451
# Accuracy train: 0.42
# Accuracy val: 0.42
# 2022-03-20 00:10:17.148176 Epoch 10, Training loss 1.0616125284558366
# Accuracy train: 0.62
# Accuracy val: 0.56
# 2022-03-20 00:11:56.026092 Epoch 20, Training loss 0.648580199007488
# Accuracy train: 0.75
# Accuracy val: 0.59
# 2022-03-20 00:13:34.694001 Epoch 30, Training loss 0.34556875762808353
# Accuracy train: 0.84
# Accuracy val: 0.58
# 2022-03-20 00:15:13.587998 Epoch 40, Training loss 0.1712465749391357
# Accuracy train: 0.91
# Accuracy val: 0.57
# 2022-03-20 00:16:52.440839 Epoch 50, Training loss 0.09240160246505914
# Accuracy train: 0.95
# Accuracy val: 0.57
# 2022-03-20 00:18:31.254326 Epoch 60, Training loss 0.055751043345655324
# Accuracy train: 0.98
# Accuracy val: 0.57
# 2022-03-20 00:20:10.507786 Epoch 70, Training loss 0.037175594836168585
# Accuracy train: 0.99
# Accuracy val: 0.57
# 2022-03-20 00:21:48.968865 Epoch 80, Training loss 0.02698798025446132
# Accuracy train: 0.99
# Accuracy val: 0.57
# 2022-03-20 00:23:27.113175 Epoch 90, Training loss 0.020755827181574787
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:25:05.177491 Epoch 100, Training loss 0.016668063618809632
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:26:44.134902 Epoch 110, Training loss 0.013689011238012796
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:28:22.471167 Epoch 120, Training loss 0.011592395837380625
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:30:01.632138 Epoch 130, Training loss 0.010015043660479091
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:31:40.293537 Epoch 140, Training loss 0.008827230463738142
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:33:18.622229 Epoch 150, Training loss 0.007866828978095023
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:34:57.635181 Epoch 160, Training loss 0.0070360783425628985
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:36:36.223867 Epoch 170, Training loss 0.0062870053353223975
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:38:15.209187 Epoch 180, Training loss 0.005704835936774874
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:39:54.318108 Epoch 190, Training loss 0.0052222774899683775
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:41:33.622903 Epoch 200, Training loss 0.004814255888998994
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:43:13.072793 Epoch 210, Training loss 0.004475481869370612
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:44:51.269426 Epoch 220, Training loss 0.004162181909714142
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:46:29.379142 Epoch 230, Training loss 0.0039046023033864207
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:48:08.155943 Epoch 240, Training loss 0.003675164190529491
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:49:46.733599 Epoch 250, Training loss 0.003435640662248768
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:51:25.412897 Epoch 260, Training loss 0.0032459242558053186
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:53:04.400851 Epoch 270, Training loss 0.0030743717976674306
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:54:42.981569 Epoch 280, Training loss 0.0029200470144830674
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:56:21.951013 Epoch 290, Training loss 0.0027702294165462666
# Accuracy train: 1.00
# Accuracy val: 0.57
# 2022-03-20 00:58:00.880030 Epoch 300, Training loss 0.002614096118359948
# Accuracy train: 1.00
# Accuracy val: 0.57
# Accuracy train: 1.00
# Accuracy val: 0.57
# {'train': 0.99994, 'val': 0.5708}

# %%
model2 = NetWidth2().to(device=device)
optimizer = optim.SGD(model2.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 300,
    optimizer = optimizer,
    model = model2,
    loss_fn = loss_fn,
    train_loader = train_loader,
)

validate(model2, train_loader, val_loader)
# Out:
# 2022-03-20 00:58:15.778759 Epoch 1, Training loss 1.9827871834835433
# Accuracy train: 0.39
# Accuracy val: 0.39
# 2022-03-20 00:59:15.796367 Epoch 10, Training loss 1.067048784945627
# Accuracy train: 0.62
# Accuracy val: 0.60
# 2022-03-20 01:00:22.168403 Epoch 20, Training loss 0.8343745812278269
# Accuracy train: 0.70
# Accuracy val: 0.66
# 2022-03-20 01:01:28.384854 Epoch 30, Training loss 0.7350310712595425
# Accuracy train: 0.74
# Accuracy val: 0.69
# 2022-03-20 01:02:34.475215 Epoch 40, Training loss 0.6636746202588386
# Accuracy train: 0.77
# Accuracy val: 0.69
# 2022-03-20 01:03:40.683420 Epoch 50, Training loss 0.6044617405023112
# Accuracy train: 0.79
# Accuracy val: 0.69
# 2022-03-20 01:04:47.125925 Epoch 60, Training loss 0.5531179899221186
# Accuracy train: 0.81
# Accuracy val: 0.68
# 2022-03-20 01:05:53.133607 Epoch 70, Training loss 0.5068753277287459
# Accuracy train: 0.82
# Accuracy val: 0.68
# 2022-03-20 01:06:58.821882 Epoch 80, Training loss 0.4645010269701938
# Accuracy train: 0.83
# Accuracy val: 0.67
# 2022-03-20 01:08:04.545252 Epoch 90, Training loss 0.42587747114241276
# Accuracy train: 0.84
# Accuracy val: 0.67
# 2022-03-20 01:09:10.232468 Epoch 100, Training loss 0.3908321240445232
# Accuracy train: 0.85
# Accuracy val: 0.66
# 2022-03-20 01:10:15.916643 Epoch 110, Training loss 0.35874586095056876
# Accuracy train: 0.86
# Accuracy val: 0.66
# 2022-03-20 01:11:22.255000 Epoch 120, Training loss 0.32926284314116555
# Accuracy train: 0.86
# Accuracy val: 0.65
# 2022-03-20 01:12:28.213242 Epoch 130, Training loss 0.30222229467099887
# Accuracy train: 0.86
# Accuracy val: 0.65
# 2022-03-20 01:13:34.046454 Epoch 140, Training loss 0.2773623358544029
# Accuracy train: 0.87
# Accuracy val: 0.64
# 2022-03-20 01:14:40.241157 Epoch 150, Training loss 0.254514307803129
# Accuracy train: 0.87
# Accuracy val: 0.64
# 2022-03-20 01:15:46.231844 Epoch 160, Training loss 0.23366747385896075
# Accuracy train: 0.87
# Accuracy val: 0.64
# 2022-03-20 01:16:51.579211 Epoch 170, Training loss 0.21458818639159355
# Accuracy train: 0.87
# Accuracy val: 0.64
# 2022-03-20 01:17:56.925671 Epoch 180, Training loss 0.19705939625420837
# Accuracy train: 0.88
# Accuracy val: 0.63
# 2022-03-20 01:19:03.027103 Epoch 190, Training loss 0.18114158680753026
# Accuracy train: 0.88
# Accuracy val: 0.63
# 2022-03-20 01:20:09.367187 Epoch 200, Training loss 0.1665316914848964
# Accuracy train: 0.88
# Accuracy val: 0.63
# 2022-03-20 01:21:15.449139 Epoch 210, Training loss 0.15312508053010535
# Accuracy train: 0.88
# Accuracy val: 0.63
# 2022-03-20 01:22:21.753274 Epoch 220, Training loss 0.14102581619759044
# Accuracy train: 0.89
# Accuracy val: 0.63
# 2022-03-20 01:23:28.101030 Epoch 230, Training loss 0.13011720366871266
# Accuracy train: 0.89
# Accuracy val: 0.63
# 2022-03-20 01:24:34.333340 Epoch 240, Training loss 0.12017652100604742
# Accuracy train: 0.89
# Accuracy val: 0.63
# 2022-03-20 01:25:40.447120 Epoch 250, Training loss 0.11125578975204921
# Accuracy train: 0.89
# Accuracy val: 0.63
# 2022-03-20 01:26:46.599256 Epoch 260, Training loss 0.10313661512025558
# Accuracy train: 0.90
# Accuracy val: 0.62
# 2022-03-20 01:27:53.163422 Epoch 270, Training loss 0.09587671757554231
# Accuracy train: 0.90
# Accuracy val: 0.62
# 2022-03-20 01:28:59.084373 Epoch 280, Training loss 0.08936439929744396
# Accuracy train: 0.90
# Accuracy val: 0.62
# 2022-03-20 01:30:04.861678 Epoch 290, Training loss 0.0834906881536974
# Accuracy train: 0.90
# Accuracy val: 0.62
# 2022-03-20 01:31:10.649713 Epoch 300, Training loss 0.07824716009818913
# Accuracy train: 0.90
# Accuracy val: 0.62
# Accuracy train: 0.90
# Accuracy val: 0.62
# {'train': 0.90468, 'val': 0.6211}

# %% [markdown]
# Problem 2

# %%
class ResBlock(nn.Module):
    def __init__(self, n_chans):
        super(ResBlock, self).__init__()
        self.conv = nn.Conv2d(n_chans, n_chans, kernel_size=3,
                              padding=1, bias=False)  # <1>
        self.batch_norm = nn.BatchNorm2d(num_features=n_chans)
        torch.nn.init.kaiming_normal_(self.conv.weight,
                                      nonlinearity='relu')  # <2>
        torch.nn.init.constant_(self.batch_norm.weight, 0.5)
        torch.nn.init.zeros_(self.batch_norm.bias)

    def forward(self, x):
        out = self.conv(x)
        out = self.batch_norm(out)
        out = torch.relu(out)
        return out + x

# %%
class NetResDeep(nn.Module):
    def __init__(self, n_chans1=32, n_blocks=10):
        super().__init__()
        self.n_chans1 = n_chans1
        self.conv1 = nn.Conv2d(3, n_chans1, kernel_size=3, padding=1)
        self.resblocks = nn.Sequential(
            *(n_blocks * [ResBlock(n_chans=n_chans1)]))
        self.fc1 = nn.Linear(8 * 8 * n_chans1, 32)
        self.fc2 = nn.Linear(32, 10)
        
    def forward(self, x):
        out = F.max_pool2d(torch.relu(self.conv1(x)), 2)
        out = self.resblocks(out)
        out = F.max_pool2d(out, 2)
        out = out.view(-1, 8 * 8 * self.n_chans1)
        out = torch.relu(self.fc1(out))
        out = self.fc2(out)
        return out

class NetResDeepDropout(nn.Module):
    def __init__(self, n_chans1=32, n_blocks=10):
        super().__init__()
        self.n_chans1 = n_chans1
        self.conv1 = nn.Conv2d(3, n_chans1, kernel_size=3, padding=1)
        self.resblocks = nn.Sequential(
            *(n_blocks * [ResBlock(n_chans=n_chans1)]))
        self.fc1 = nn.Linear(8 * 8 * n_chans1, 32)
        self.fc2 = nn.Linear(32, 10)
        self.dropout2d = nn.Dropout2d(p=0.3)
        self.dropout = nn.Dropout(p=0.3)
        
    def forward(self, x):
        out = F.max_pool2d(torch.relu(self.conv1(x)), 2)
        out = self.dropout2d(out)
        out = self.resblocks(out)
        out = F.max_pool2d(out, 2)
        out = self.dropout2d(out)
        out = out.view(-1, 8 * 8 * self.n_chans1)
        out = torch.relu(self.fc1(out))
        out = self.dropout(out)
        out = self.fc2(out)
        return out

class NetResDeepBatchNorm(nn.Module):
    def __init__(self, n_chans1=32, n_blocks=10):
        super().__init__()
        self.n_chans1 = n_chans1
        self.conv1 = nn.Conv2d(3, n_chans1, kernel_size=3, padding=1)
        self.conv1_norm = nn.BatchNorm2d(n_chans1)
        self.resblocks = nn.Sequential(
            *(n_blocks * [ResBlock(n_chans=n_chans1)]))
        self.fc1 = nn.Linear(8 * 8 * n_chans1, 32)
        self.fc1_norm = nn.BatchNorm1d(32)
        self.fc2 = nn.Linear(32, 10)
        
    def forward(self, x):
        out = F.max_pool2d(torch.relu(self.conv1_norm(self.conv1(x))), 2)
        out = self.resblocks(out)
        out = F.max_pool2d(out, 2)
        out = out.view(-1, 8 * 8 * self.n_chans1)
        out = torch.relu(self.fc1_norm(self.fc1(out)))
        out = self.fc2(out)
        return out

# %%
model = NetResDeep(n_chans1=32, n_blocks=10).to(device=device)
optimizer = optim.SGD(model.parameters(), lr=3e-3)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 200,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# validate(model, train_loader, val_loader)
# Out:
# 2022-03-22 00:12:53.464905 Epoch 1, Training loss 1.7507648257648243
# Accuracy train: 0.41
# Accuracy val: 0.40
# 2022-03-22 00:16:04.149449 Epoch 10, Training loss 0.8832015352480856
# Accuracy train: 0.68
# Accuracy val: 0.64
# 2022-03-22 00:19:35.255654 Epoch 20, Training loss 0.6757848311949264
# Accuracy train: 0.76
# Accuracy val: 0.67
# 2022-03-22 00:23:06.479471 Epoch 30, Training loss 0.5441320890851338
# Accuracy train: 0.80
# Accuracy val: 0.67
# 2022-03-22 00:26:37.489273 Epoch 40, Training loss 0.43137307158287835
# Accuracy train: 0.82
# Accuracy val: 0.66
# 2022-03-22 00:30:08.721498 Epoch 50, Training loss 0.3384645460054393
# Accuracy train: 0.85
# Accuracy val: 0.66
# 2022-03-22 00:33:39.842219 Epoch 60, Training loss 0.27541364037700933
# Accuracy train: 0.85
# Accuracy val: 0.65
# 2022-03-22 00:37:11.128845 Epoch 70, Training loss 0.2361571470042095
# Accuracy train: 0.87
# Accuracy val: 0.65
# 2022-03-22 00:40:42.243754 Epoch 80, Training loss 0.18915058438287444
# Accuracy train: 0.88
# Accuracy val: 0.64
# 2022-03-22 00:44:13.292809 Epoch 90, Training loss 0.1463706560428147
# Accuracy train: 0.89
# Accuracy val: 0.64
# 2022-03-22 00:47:44.181195 Epoch 100, Training loss 0.0885786512447402
# Accuracy train: 0.91
# Accuracy val: 0.65
# 2022-03-22 00:51:14.416122 Epoch 110, Training loss 0.052872266694831915
# Accuracy train: 0.93
# Accuracy val: 0.65
# 2022-03-22 00:54:45.211615 Epoch 120, Training loss 0.0443712916151356
# Accuracy train: 0.94
# Accuracy val: 0.65
# 2022-03-22 00:58:16.152280 Epoch 130, Training loss 0.011651969263496835
# Accuracy train: 0.96
# Accuracy val: 0.65
# 2022-03-22 01:01:47.045258 Epoch 140, Training loss 0.007102222246019041
# Accuracy train: 0.97
# Accuracy val: 0.65
# 2022-03-22 01:05:17.952849 Epoch 150, Training loss 0.005023987577630259
# Accuracy train: 0.98
# Accuracy val: 0.65
# 2022-03-22 01:08:48.934111 Epoch 160, Training loss 0.003817933453919838
# Accuracy train: 0.98
# Accuracy val: 0.65
# 2022-03-22 01:12:19.636905 Epoch 170, Training loss 0.0030476178095885614
# Accuracy train: 0.99
# Accuracy val: 0.65
# 2022-03-22 01:15:50.364259 Epoch 180, Training loss 0.0025132072316405253
# Accuracy train: 0.99
# Accuracy val: 0.65
# 2022-03-22 01:19:20.613330 Epoch 190, Training loss 0.002111339506589274
# Accuracy train: 0.99
# Accuracy val: 0.65
# 2022-03-22 01:22:51.001110 Epoch 200, Training loss 0.001804120057304759
# Accuracy train: 1.00
# Accuracy val: 0.65

# %%
model2 = NetResDeep(n_chans1=32, n_blocks=10).to(device=device)
optimizer = optim.SGD(model2.parameters(), lr=3e-3,  weight_decay=1e-4)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 200,
    optimizer = optimizer,
    model = model2,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# validate(model2, train_loader, val_loader)
# Out:
# 2022-03-22 15:30:25.713659 Epoch 1, Training loss 1.736941417007495
# Accuracy train: 0.34
# Accuracy val: 0.34
# 2022-03-22 15:33:34.052711 Epoch 10, Training loss 0.9380189663613848
# Accuracy train: 0.65
# Accuracy val: 0.61
# 2022-03-22 15:37:02.250452 Epoch 20, Training loss 0.7215486439826239
# Accuracy train: 0.74
# Accuracy val: 0.66
# 2022-03-22 15:40:30.371824 Epoch 30, Training loss 0.5860441800044931
# Accuracy train: 0.78
# Accuracy val: 0.66
# 2022-03-22 15:43:58.280817 Epoch 40, Training loss 0.471880220543698
# Accuracy train: 0.81
# Accuracy val: 0.66
# 2022-03-22 15:47:26.161063 Epoch 50, Training loss 0.37581508036922007
# Accuracy train: 0.83
# Accuracy val: 0.64
# 2022-03-22 15:50:54.053254 Epoch 60, Training loss 0.30170636885153973
# Accuracy train: 0.84
# Accuracy val: 0.64
# 2022-03-22 15:54:21.894902 Epoch 70, Training loss 0.24483407838532076
# Accuracy train: 0.84
# Accuracy val: 0.63
# 2022-03-22 15:57:49.754775 Epoch 80, Training loss 0.1965501949791332
# Accuracy train: 0.81
# Accuracy val: 0.61
# 2022-03-22 16:01:17.412006 Epoch 90, Training loss 0.17810231087553074
# Accuracy train: 0.89
# Accuracy val: 0.64
# 2022-03-22 16:04:45.195288 Epoch 100, Training loss 0.17401471550045225
# Accuracy train: 0.87
# Accuracy val: 0.63
# 2022-03-22 16:08:12.597683 Epoch 110, Training loss 0.11926854901192019
# Accuracy train: 0.90
# Accuracy val: 0.63
# 2022-03-22 16:11:40.243003 Epoch 120, Training loss 0.051723415606662326
# Accuracy train: 0.92
# Accuracy val: 0.63
# 2022-03-22 16:15:07.717737 Epoch 130, Training loss 0.02909308941195221
# Accuracy train: 0.94
# Accuracy val: 0.63
# 2022-03-22 16:18:35.100513 Epoch 140, Training loss 0.00978727590368913
# Accuracy train: 0.96
# Accuracy val: 0.63
# 2022-03-22 16:22:02.555743 Epoch 150, Training loss 0.0063650657877187865
# Accuracy train: 0.97
# Accuracy val: 0.63
# 2022-03-22 16:25:29.924879 Epoch 160, Training loss 0.004705303321804499
# Accuracy train: 0.98
# Accuracy val: 0.63
# 2022-03-22 16:28:57.280936 Epoch 170, Training loss 0.003698573370649934
# Accuracy train: 0.98
# Accuracy val: 0.63
# 2022-03-22 16:32:24.862028 Epoch 180, Training loss 0.0030278497000547637
# Accuracy train: 0.99
# Accuracy val: 0.63
# 2022-03-22 16:35:52.380787 Epoch 190, Training loss 0.002547000441715107
# Accuracy train: 0.99
# Accuracy val: 0.63
# 2022-03-22 16:39:20.027388 Epoch 200, Training loss 0.002194195610347211
# Accuracy train: 0.99
# Accuracy val: 0.63

# %%
model3 = NetResDeepDropout(n_chans1=32, n_blocks=10).to(device=device)
optimizer = optim.SGD(model3.parameters(), lr=9e-3)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 300,
    optimizer = optimizer,
    model = model3,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# validate(model3, train_loader, val_loader)
# Out:
# 2022-03-22 22:54:50.094471 Epoch 1, Training loss 2.144991959604766
# Accuracy train: 0.24
# Accuracy val: 0.24
# 2022-03-22 22:58:01.489169 Epoch 10, Training loss 1.4980751986393843
# Accuracy train: 0.43
# Accuracy val: 0.43
# 2022-03-22 23:01:33.987559 Epoch 20, Training loss 1.3424742673059253
# Accuracy train: 0.52
# Accuracy val: 0.50
# 2022-03-22 23:05:06.428735 Epoch 30, Training loss 1.2730646330072446
# Accuracy train: 0.53
# Accuracy val: 0.52
# 2022-03-22 23:08:38.710578 Epoch 40, Training loss 1.2343927220920163
# Accuracy train: 0.55
# Accuracy val: 0.52
# 2022-03-22 23:12:10.760015 Epoch 50, Training loss 1.1940795218243319
# Accuracy train: 0.57
# Accuracy val: 0.55
# 2022-03-22 23:15:42.983597 Epoch 60, Training loss 1.1613170257614702
# Accuracy train: 0.57
# Accuracy val: 0.55
# 2022-03-22 23:19:15.193591 Epoch 70, Training loss 1.1515594824500706
# Accuracy train: 0.58
# Accuracy val: 0.55
# 2022-03-22 23:22:47.534858 Epoch 80, Training loss 1.1194788520141026
# Accuracy train: 0.59
# Accuracy val: 0.56
# 2022-03-22 23:26:19.969690 Epoch 90, Training loss 1.1057955945849114
# Accuracy train: 0.58
# Accuracy val: 0.56
# 2022-03-22 23:29:52.347495 Epoch 100, Training loss 1.0896958145491606
# Accuracy train: 0.60
# Accuracy val: 0.57
# 2022-03-22 23:33:24.463925 Epoch 110, Training loss 1.0662816385631366
# Accuracy train: 0.62
# Accuracy val: 0.59
# 2022-03-22 23:36:57.051531 Epoch 120, Training loss 1.0483162965615997
# Accuracy train: 0.62
# Accuracy val: 0.58
# 2022-03-22 23:40:29.462923 Epoch 130, Training loss 1.0367193555892886
# Accuracy train: 0.63
# Accuracy val: 0.58
# 2022-03-22 23:44:01.644286 Epoch 140, Training loss 1.0226085554150974
# Accuracy train: 0.62
# Accuracy val: 0.59
# 2022-03-22 23:47:34.063527 Epoch 150, Training loss 1.021892540137786
# Accuracy train: 0.64
# Accuracy val: 0.60
# 2022-03-22 23:51:06.370490 Epoch 160, Training loss 1.0131580216805343
# Accuracy train: 0.63
# Accuracy val: 0.59
# 2022-03-22 23:54:38.887414 Epoch 170, Training loss 1.0016158585200834
# Accuracy train: 0.64
# Accuracy val: 0.60
# 2022-03-22 23:58:10.947962 Epoch 180, Training loss 0.9981411266357393
# Accuracy train: 0.65
# Accuracy val: 0.60
# 2022-03-23 00:01:43.175890 Epoch 190, Training loss 0.9910082122706392
# Accuracy train: 0.64
# Accuracy val: 0.61
# 2022-03-23 00:05:15.326451 Epoch 200, Training loss 0.9838226295035818
# Accuracy train: 0.64
# Accuracy val: 0.60
# 2022-03-23 00:08:47.305205 Epoch 210, Training loss 0.9877368920599409
# Accuracy train: 0.65
# Accuracy val: 0.61
# 2022-03-23 00:12:19.093885 Epoch 220, Training loss 0.9758188402103951
# Accuracy train: 0.65
# Accuracy val: 0.60
# 2022-03-23 00:15:51.283183 Epoch 230, Training loss 0.9675779069780999
# Accuracy train: 0.65
# Accuracy val: 0.61
# 2022-03-23 00:19:23.498795 Epoch 240, Training loss 0.9672797958716712
# Accuracy train: 0.64
# Accuracy val: 0.60
# 2022-03-23 00:22:55.531513 Epoch 250, Training loss 0.9649870785148552
# Accuracy train: 0.65
# Accuracy val: 0.61
# 2022-03-23 00:26:27.589939 Epoch 260, Training loss 0.9577878889677774
# Accuracy train: 0.65
# Accuracy val: 0.60
# 2022-03-23 00:29:59.674114 Epoch 270, Training loss 0.9637430482508277
# Accuracy train: 0.65
# Accuracy val: 0.60
# 2022-03-23 00:33:31.531055 Epoch 280, Training loss 0.960840864102249
# Accuracy train: 0.65
# Accuracy val: 0.60
# 2022-03-23 00:37:03.243742 Epoch 290, Training loss 0.9515703034675335
# Accuracy train: 0.65
# Accuracy val: 0.61
# 2022-03-23 00:40:35.015503 Epoch 300, Training loss 0.9479589150537311
# Accuracy train: 0.66
# Accuracy val: 0.61

# %%
model4 = NetResDeepBatchNorm(n_chans1=32, n_blocks=10).to(device=device)
optimizer = optim.SGD(model4.parameters(), lr=3e-3)
loss_fn = nn.CrossEntropyLoss()

training_loop(
    n_epochs = 200,
    optimizer = optimizer,
    model = model4,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# validate(model4, train_loader, val_loader)
# Out:
# 2022-03-22 01:23:20.041551 Epoch 1, Training loss 1.8864518004610105
# Accuracy train: 0.45
# Accuracy val: 0.45
# 2022-03-22 01:26:38.942740 Epoch 10, Training loss 0.9291007843468805
# Accuracy train: 0.70
# Accuracy val: 0.64
# 2022-03-22 01:30:23.637627 Epoch 20, Training loss 0.6740351446982845
# Accuracy train: 0.79
# Accuracy val: 0.66
# 2022-03-22 01:34:04.159802 Epoch 30, Training loss 0.521326186330727
# Accuracy train: 0.84
# Accuracy val: 0.66
# 2022-03-22 01:37:48.669873 Epoch 40, Training loss 0.4083817498782254
# Accuracy train: 0.87
# Accuracy val: 0.64
# 2022-03-22 01:41:29.185785 Epoch 50, Training loss 0.31791943403156214
# Accuracy train: 0.89
# Accuracy val: 0.63
# 2022-03-22 01:45:13.897219 Epoch 60, Training loss 0.2436674494591668
# Accuracy train: 0.91
# Accuracy val: 0.63
# 2022-03-22 01:48:54.429783 Epoch 70, Training loss 0.1840492696941966
# Accuracy train: 0.93
# Accuracy val: 0.62
# 2022-03-22 01:52:39.256938 Epoch 80, Training loss 0.13698897474562116
# Accuracy train: 0.94
# Accuracy val: 0.62
# 2022-03-22 01:56:18.665568 Epoch 90, Training loss 0.1010778440029153
# Accuracy train: 0.95
# Accuracy val: 0.62
# 2022-03-22 02:00:01.480177 Epoch 100, Training loss 0.0752019394031914
# Accuracy train: 0.96
# Accuracy val: 0.61
# 2022-03-22 02:03:41.460160 Epoch 110, Training loss 0.05727842417509888
# Accuracy train: 0.97
# Accuracy val: 0.61
# 2022-03-22 02:07:26.529427 Epoch 120, Training loss 0.044765215650524784
# Accuracy train: 0.98
# Accuracy val: 0.61
# 2022-03-22 02:11:07.228361 Epoch 130, Training loss 0.03602605449902775
# Accuracy train: 0.98
# Accuracy val: 0.61
# 2022-03-22 02:14:50.034634 Epoch 140, Training loss 0.02974627138344128
# Accuracy train: 0.99
# Accuracy val: 0.61
# 2022-03-22 02:18:29.449692 Epoch 150, Training loss 0.02509868696755956
# Accuracy train: 0.99
# Accuracy val: 0.61
# 2022-03-22 02:22:13.784538 Epoch 160, Training loss 0.021522645599773283
# Accuracy train: 0.99
# Accuracy val: 0.61
# 2022-03-22 02:25:54.053764 Epoch 170, Training loss 0.01872692053632625
# Accuracy train: 0.99
# Accuracy val: 0.61
# 2022-03-22 02:29:38.925049 Epoch 180, Training loss 0.016496714339127094
# Accuracy train: 0.99
# Accuracy val: 0.61
# 2022-03-22 02:33:19.850724 Epoch 190, Training loss 0.014713521408455452
# Accuracy train: 1.00
# Accuracy val: 0.61
# 2022-03-22 02:37:04.817109 Epoch 200, Training loss 0.013207806825406773
# Accuracy train: 1.00
# Accuracy val: 0.61
